# %% [markdown]
# <!-- Projeto Desenvolvido na Data Science Academy - www.datascienceacademy.com.br -->
# # <font color='blue'>Data Science Academy</font>
# ## <font color='blue'>Matemática e Estatística Aplicada Para Data Science, Machine Learning e IA</font>
# ## <font color='blue'>Projeto 2</font>
# ### <font color='blue'>Construindo Algoritmo de Rede Neural Artificial Através de Operações com Matrizes</font>

# %% [markdown]
# ## Instalando e Carregando os Pacotes

# %%
# Para atualizar um pacote, execute o comando abaixo no terminal ou prompt de comando:
# pip install -U nome_pacote

# Para instalar a versão exata de um pacote, execute o comando abaixo no terminal ou prompt de comando:
# !pip install nome_pacote==versão_desejada

# Depois de instalar ou atualizar o pacote, reinicie o jupyter notebook.

# Instala o pacote watermark. 
# Esse pacote é usado para gravar as versões de outros pacotes usados neste jupyter notebook.
#!pip install -q -U watermark

# %%
# Imports
import numpy as np

# %%
# Versões dos pacotes usados neste jupyter notebook
# %reload_ext watermark
# %watermark -a "Data Science Academy"
# Out:
# Author: Data Science Academy

# %% [markdown]
# ## Parte 1 - Escrever o Algoritmo

# %%
# Classe para definição do algoritmo
class AlgoritmoNeuralNetworkDSA:
    
    # Método construtor (inicializa atributos da classe quando um objeto for criado)
    def __init__(self, taxa_aprendizado, num_iteracoes):
        
        # Inicializa os atributos da classe com os valores passados como argumento 
        self.taxa_aprendizado = taxa_aprendizado
        self.num_iteracoes = num_iteracoes
        
        # Inicializa os coeficientes com None (isso é o que o modelo irá aprender)
        self.pesos = None
        self.bias = None
        
    # Método da função de ativação sigmóide para gerar a previsão no formato que pode ser interpretado
    # como probabilidade (valores entre 0 e 1 para cada classe prevista)
    def func_activation_sigmoid(self, pred):
        
        # Fórmula da função sigmóide
        sig = 1 / (1 + np.exp(-pred))
        
        return sig
    
    # Método de treinamento
    def fit(self, X, y):
        
        # Extrai do shape o número de linhas e de colunas do conjunto de dados
        num_registros, num_atributos = X.shape

        # Inicializa a matriz de pesos com valores iguais a zero no mesmo shape do número de atributos
        self.pesos = np.zeros(num_atributos)

        # Inicializa o escalar bias com valor zero
        self.bias = 0
        
        print('\nTreinamento Iniciado!')
        
        # Loop de treinamento pelo número de iterações
        for i in range(self.num_iteracoes):
            
            print('\nTreinamento do Modelo na Iteração', i)
            
            # Primeira parte do método fit é o forward pass (passada para frente)
            
            # Faz a previsão usando o valor de X (dados de entrada), pesos e bias
            previsao = np.dot(X, self.pesos) + self.bias
            print('Previsão antes da função de ativação:', previsao)
            
            # Converte a previsão no formato que pode ser interpretado como probabilidade usando função sigmóide
            previsao_final = self.func_activation_sigmoid(previsao)
            print('Previsão depois da função de ativação:', previsao_final)
            
            # Calcula o erro do modelo com o valor real do dado de saída y
            # Exemplo: previsao_final = 0.1, y = 0
            # Exemplo: previsao_final = 0.4, y = 0
            erro = (previsao_final - y)
            print('Erro do modelo:', erro)
            
            # Segunda parte do método fit é o backward pass (passada para trás ou backpropagation)

            # Calcula os gradientes (derivadas da matriz de pesos e do bias)
            dw = (1 / num_registros) * np.dot(X.T, erro)
            db = (1 / num_registros) * np.sum(previsao_final - y)

            # Atualiza os pesos e bias usando o valor das derivadas e a taxa de aprendizado

            # Fórmula: pesos - taxa-aprendizado x derivada dos pesos
            self.pesos -= self.taxa_aprendizado * dw
            print('Valores de pesos:', self.pesos)

            # Fórmula: bias - taxa-aprendizado x derivada do bias
            self.bias -= self.taxa_aprendizado * db
            print('Valor de bias:', self.bias)
        
        print('\nTreinamento Concluído!')

    # Método para as previsões
    def predict(self, X):
        
        # Faz as previsões com novos dados de entrada e com os valores aprendidos de pesos e bias
        previsao = np.dot(X, self.pesos) + self.bias
        print('Previsão antes de passar pela função de ativação:', previsao)
        
        # Converte as previsões no formato de probabilidade usando função sigmóide
        previsao_final = self.func_activation_sigmoid(previsao)
        print('Previsão depois de passar pela função de ativação:', previsao_final)
        
        # Aplica o cut-off e converte probabilidades para classes binárias (0 ou 1)
        classe_prevista = [1 if i > 0.5 else 0 for i in previsao_final]
        
        return classe_prevista

# %% [markdown]
# ## Parte 2 - Preparar os Dados de Treino e Teste

# %%
# Os dados de entrada representam (por exemplo) número de compras em uma transação comercial
# Temos 2 atributos (variáveis) e 8 registros (linhas ou observações ou exemplos)
dados_entrada = np.array([[1, 2.5], [2, 3], [3, 5], [1, 4], [1.5, 2], [5, 6], [6, 7], [4, 5.5]])

# %%
dados_entrada
# Out:
# array([[1. , 2.5],
#        [2. , 3. ],
#        [3. , 5. ],
#        [1. , 4. ],
#        [1.5, 2. ],
#        [5. , 6. ],
#        [6. , 7. ],
#        [4. , 5.5]])

# %%
# Os dados de saída representam (por exemplo) se a transação foi ou não suspeita
# Temos 8 itens, um para cada linha dos dados de entrada
dados_saida = np.array([0, 0, 1, 0, 1, 0, 1, 1])

# %%
dados_saida
# Out:
# array([0, 0, 1, 0, 1, 0, 1, 1])

# %% [markdown]
# - Classe 0 = Não é Transação Suspeita
# - Classe 1 = É Transação Suspeita

# %% [markdown]
# > Vamos usar 6 registros para treinar o modelo e 2 para avaliar o modelo depois de treinado.

# %%
# Dados de entrada e saída para treinar o modelo 
X_treino = np.array([[1, 2.5], [2, 3], [3, 5], [1, 4], [5, 6], [6, 7]])
y_treino = np.array([0, 0, 1, 0, 1, 1])

# %% [markdown]
# ## Parte 3 - Treinamento do Modelo

# %%
# Define os hiperparâmetros (controlam o processo de treinamento)
taxa_aprendizado = 0.01
num_iteracoes = 1000

# %%
# Cria o modelo a partir da classe (cria instância da classe, ou seja, um objeto)
modelo_dsa = AlgoritmoNeuralNetworkDSA(taxa_aprendizado, num_iteracoes)

# %%
# Treina o modelo
modelo_dsa.fit(X_treino, y_treino)
# Out:
# Treinamento Iniciado!
#
# Treinamento do Modelo na Iteração 0
# Previsão antes da função de ativação: [0. 0. 0. 0. 0. 0.]
# Previsão depois da função de ativação: [0.5 0.5 0.5 0.5 0.5 0.5]
# Erro do modelo: [ 0.5  0.5 -0.5  0.5 -0.5 -0.5]
# Valores de pesos: [0.00833333 0.00708333]
# Valor de bias: 0.0
#
# Treinamento do Modelo na Iteração 1
# Previsão antes da função de ativação: [0.02604167 0.03791667 0.06041667 0.03666667 0.08416667 0.09958333]
# Previsão depois da função de ativação: [0.50651005 0.50947803 0.51509957 0.50916564 0.52102925 0.52487528]
# Erro do modelo: [ 0.50651005  0.50947803 -0.48490043  0.50916564 -0.47897075 -0.47512472]
# Valores de pesos: [0.01610945 0.01340471]
# Valor de bias: -0.00014359637866319386
#
# Treinamento do Modelo na Iteração 2
# Previsão antes da função de ativação: [0.04947764 0.07228945 0.11520833 0.06958471 0.16083195 0.19034611]
# Previsão depois da função de ativação: [0.51236689 0.5180645  0.52877027 0.51738916 0.54012154 0.54744337]
# Erro do modelo: [ 0.51236689  0.5180645  -0.47122973  0.51738916 -0.45987846 -0.45255663]
# Valores de pesos: [0.02338035 0.01903579]
# Valor de bias: -0.0004171892415436455
#
# Treinamento do Modelo na Iteração 3
# Previsão antes da função de ativação: [0.07055264 0.10345089 0.16490282 0.09910633 0.23069931 0.27311545]
# Previsão depois da função de ativação: [0.51763085 0.52583968 0.54113254 0.52475632 0.55742038 0.56785758]
# Erro do modelo: [ 0.51763085  0.52583968 -0.45886746  0.52475632 -0.44257962 -0.43214242]
# Valores de pesos: [0.03019416 0.02404278]
# Valor de bias: -0.0008082514982085744
#
# Treinamento do Modelo na Iteração 4
# Previsão antes da função de ativação: [0.08949285 0.1317084  0.20998812 0.12555702 0.29441922 0.34865616]
# Previsão depois da função de ativação: [0.52235829 0.53287958 0.55230497 0.53134808 0.57307769 0.58629166]
# Erro do modelo: [ 0.52235829  0.53287958 -0.44769503  0.53134808 -0.42692231 -0.41370834]
# Valores de pesos: [0.03659496 0.02848618]
# Valor de bias: -0.0013053519674890446
#
# Treinamento do Modelo na Iteração 5
# Previsão antes da função de ativação: [0.10650506 0.15734311 0.25091043 0.14923433 0.35258653 0.41766768]
# Previsão depois da função de ativação: [0.52660112 0.53925483 0.56240058 0.53723949 0.58724467 0.60292501]
# Erro do modelo: [ 0.52660112  0.53925483 -0.43759942  0.53723949 -0.41275533 -0.39707499]
# Valores de pesos: [0.04262275 0.03242089]
# Valor de bias: -0.0018981281277482315
#
# Treinamento do Modelo na Iteração 6
# Previsão antes da função de ativação: [0.12177686 0.18061006 0.2880746  0.1704082  0.405741   0.48078465]
# Previsão depois da função de ativação: [0.53040665 0.54503017 0.5715247  0.54249926 0.60006621 0.61793314]
# Erro do modelo: [ 0.53040665  0.54503017 -0.4284753   0.54249926 -0.39993379 -0.38206686]
# Valores de pesos: [0.04831364 0.03589647]
# Valor de bias: -0.002577228342265115
#
# Treinamento do Modelo na Iteração 7
# Previsão antes da função de ativação: [0.13547757 0.20173944 0.32184601 0.18932227 0.45436975 0.53857985]
# Previsão depois da função de ativação: [0.53381768 0.5502645  0.57977407 0.5471897  0.61167768 0.63148199]
# Erro do modelo: [ 0.53381768  0.5502645  -0.42022593  0.5471897  -0.38832232 -0.36851801]
# Valores de pesos: [0.05370007 0.03895745]
# Valor de bias: -0.0033342377190682454
#
# Treinamento do Modelo na Iteração 8
# Previsão antes da função de ativação: [0.14775947 0.22093827 0.35255325 0.20619565 0.49891084 0.59156837]
# Previsão depois da função de ativação: [0.53687281 0.55501097 0.5872366  0.55136705 0.62220334 0.64372492]
# Erro do modelo: [ 0.53687281  0.55501097 -0.4127634   0.55136705 -0.37779666 -0.35627508]
# Valores de pesos: [0.05881118 0.04164385]
# Valor de bias: -0.004161597193397696
#
# Treinamento do Modelo na Iteração 9
# Previsão antes da função de ativação: [0.15875921 0.23839231 0.38049119 0.22122499 0.5397574  0.64021242]
# Previsão depois da função de ativação: [0.53960665 0.55931742 0.59399157 0.55508179 0.63175598 0.65480148]
# Erro do modelo: [ 0.53960665  0.55931742 -0.40600843  0.55508179 -0.36824402 -0.34519852]
# Valores de pesos: [0.06367303 0.04399152]
# Valor de bias: -0.005052521997025119
#
# Treinamento do Modelo na Iteração 10
# Previsão antes da função de ativação: [0.16859931 0.2542681  0.40592417 0.23458659 0.57726175 0.6849263 ]
# Previsão depois da função de ativação: [0.54205026 0.56322674 0.60011017 0.55837917 0.64043709 0.66483731]
# Erro do modelo: [ 0.54205026  0.56322674 -0.39988983  0.55837917 -0.35956291 -0.33516269]
# Valores de pesos: [0.06830899 0.04603259]
# Valor de bias: -0.006000923244238933
#
# Treinamento do Modelo na Iteração 11
# Previsão antes da função de ativação: [0.17738955 0.26871483 0.42908901 0.24643843 0.61173959 0.72608117]
# Previsão depois da função de ativação: [0.54423146 0.56677737 0.60565611 0.56129968 0.64833752 0.67394472]
# Erro do modelo: [ 0.54423146  0.56677737 -0.39434389  0.56129968 -0.35166248 -0.32605528]
# Valores de pesos: [0.07273998 0.04779588]
# Valor de bias: -0.007001334703583485
#
# Treinamento do Modelo na Iteração 12
# Previsão antes da função de ativação: [0.18522833 0.28186625 0.45019798 0.25692215 0.64347381 0.76400966]
# Previsão depois da função de ativação: [0.54617514 0.5700037  0.6106863  0.56387954 0.6555383  0.68222364]
# Erro do modelo: [ 0.54617514  0.5700037  -0.3893137   0.56387954 -0.3444617  -0.31777636]
# Valores de pesos: [0.07698472 0.04930722]
# Valor de bias: -0.008048845732862698
#
# Treinamento do Modelo na Iteração 13
# Previsão antes da função de ativação: [0.19220392 0.29384225 0.46944141 0.26616476 0.67271807 0.79901001]
# Previsão depois da função de ativação: [0.5479036  0.57293652 0.61525154 0.56615112 0.66211151 0.68976267]
# Erro do modelo: [ 0.5479036   0.57293652 -0.38474846  0.56615112 -0.33788849 -0.31023733]
# Valores de pesos: [0.08106003 0.05058982]
# Valor de bias: -0.009139040664566033
#
# Treinamento do Modelo na Iteração 14
# Previsão antes da função de ativação: [0.19839554 0.30475048 0.48699015 0.27428028 0.69970002 0.83134987]
# Previsão depois da função de ativação: [0.54943684 0.5756034  0.61939713 0.5681434  0.66812126 0.69664028]
# Erro do modelo: [ 0.54943684  0.5756034  -0.38060287  0.5681434  -0.33187874 -0.30335972]
# Valores de pesos: [0.08498098 0.05166454]
# Valor de bias: -0.010267944512270557
#
# Treinamento do Modelo na Iteração 15
# Previsão antes da função de ativação: [0.20387438 0.31468763 0.50299769 0.28137119 0.72462419 0.86126971]
# Previsão depois da função de ativação: [0.55079278 0.57802904 0.62316354 0.56988236 0.67362448 0.70292586]
# Erro do modelo: [ 0.55079278  0.57802904 -0.37683646  0.56988236 -0.32637552 -0.29707414]
# Valores de pesos: [0.08876115 0.05255013]
# Valor de bias: -0.011431974633589043
#
# Treinamento do Modelo na Iteração 16
# Previsão antes da função de ativação: [0.2087045  0.32374071 0.51760212 0.2875297  0.74767454 0.88898582]
# Previsão depois da função de ativação: [0.55198756 0.58023562 0.62658689 0.57139125 0.67867178 0.70868084]
# Erro do modelo: [ 0.55198756  0.58023562 -0.37341311  0.57139125 -0.32132822 -0.29131916]
# Valores de pesos: [0.09241272 0.05326351]
# Valor de bias: -0.012627897867528852
#
# Treinamento do Modelo na Iteração 17
# Previsão antes da função de ativação: [0.2129436  0.33198808 0.53092782 0.29283887 0.76901678 0.91469301]
# Previsão depois da função de ativação: [0.55303564 0.58224303 0.62969949 0.57269099 0.68330816 0.71395954]
# Erro do modelo: [ 0.55303564  0.58224303 -0.37030051  0.57269099 -0.31669184 -0.28604046]
# Valores de pesos: [0.09594671 0.05381994]
# Valor de bias: -0.013852792619913344
#
# Treinamento do Modelo na Iteração 18
# Previsão antes da função de ativação: [0.21664375 0.33950043 0.543087   0.29737366 0.78880035 0.93856699]
# Previsão depois da função de ativação: [0.55395009 0.58406917 0.63253024 0.57380036 0.68757368 0.71881011]
# Erro do modelo: [ 0.55395009  0.58406917 -0.36746976  0.57380036 -0.31242632 -0.28118989]
# Valores de pesos: [0.09937302 0.05423319]
# Valor de bias: -0.015104015370633125
#
# Treinamento do Modelo na Iteração 19
# Previsão antes da função de ativação: [0.21985198 0.3463416  0.554181   0.30120177 0.80716024 0.96076646]
# Previsão depois da função de ativação: [0.55474267 0.58573015 0.63510507 0.57473627 0.69150404 0.72327524]
# Erro do modelo: [ 0.55474267  0.58573015 -0.36489493  0.57473627 -0.30849596 -0.27672476]
# Valores de pesos: [0.10270065 0.05451574]
# Valor de bias: -0.01637917110189703
#
# Treinamento do Modelo na Iteração 20
# Previsão antes da função de ativação: [0.22261083 0.35256935 0.56430148 0.30438444 0.82421852 0.98143491]
# Previsão depois da função de ativação: [0.55542402 0.5872405  0.63744723 0.57551398 0.69513108 0.72739284]
# Erro do modelo: [ 0.55542402  0.5872405  -0.36255277  0.57551398 -0.30486892 -0.27260716]
# Valores de pesos: [0.10593769 0.05467889]
# Valor de bias: -0.01767608718516615
#
# Treinamento do Modelo na Iteração 21
# Previsão antes da função de ativação: [0.22495883 0.35823597 0.57353145 0.30697717 0.84008573 1.00070231]
# Previsão depois da função de ativação: [0.55600373 0.58861335 0.63957764 0.57614725 0.69848327 0.73119664]
# Erro do modelo: [ 0.55600373  0.58861335 -0.36042236  0.57614725 -0.30151673 -0.26880336]
# Valores de pesos: [0.10909151 0.05473289]
# Valor de bias: -0.01899279030848047
#
# Treinamento do Modelo na Iteração 22
# Previsão antes da função de ativação: [0.22693094 0.3633889  0.58194619 0.30903027 0.85486211 1.01868651]
# Previsão depois da função de ativação: [0.55649052 0.58986054 0.6415151  0.57664854 0.70158608 0.73471667]
# Erro do modelo: [ 0.55649052  0.58986054 -0.3584849   0.57664854 -0.29841392 -0.26528333]
# Valores de pesos: [0.11216879 0.05468704]
# Valor de bias: -0.020327486070837585
#
# Treinamento do Modelo na Iteração 23
# Previsão antes da função de ativação: [0.22855889 0.3680712  0.58961406 0.31058945 0.86863867 1.03549449]
# Previsão depois da função de ativação: [0.55689227 0.59099283 0.64327659 0.57702913 0.70446235 0.73797973]
# Erro do modelo: [ 0.55689227  0.59099283 -0.35672341  0.57702913 -0.29553765 -0.26202027]
# Valores de pesos: [0.11517558 0.0545498 ]
# Valor de bias: -0.021678540913513778
#
# Treinamento do Modelo na Iteração 24
# Previsão antes da função de ativação: [0.22987154 0.37232202 0.59659719 0.31169624 0.88149815 1.05122353]
# Previsão depois da função de ativação: [0.55721616 0.59201994 0.64487741 0.57729924 0.70713258 0.74100978]
# Erro do modelo: [ 0.55721616  0.59201994 -0.35512259  0.57729924 -0.29286742 -0.25899022]
# Valores de pesos: [0.11811739 0.05432889]
# Valor de bias: -0.02304446609832675
#
# Treinamento do Modelo na Iteração 25
# Previsão antes da função de ativação: [0.23089515 0.37617699 0.60295216 0.31238848 0.89351583 1.06596211]
# Previsão depois da função de ativação: [0.5574687  0.59295071 0.64633142 0.57746815 0.70961518 0.74382826]
# Erro do modelo: [ 0.5574687   0.59295071 -0.35366858  0.57746815 -0.29038482 -0.25617174]
# Valores de pesos: [0.12099926 0.05403132]
# Valor de bias: -0.02442390347919501
#
# Treinamento do Modelo na Iteração 26
# Previsão antes da função de ativação: [0.23165365 0.37966858 0.60873047 0.31270063 0.90476032 1.0797909 ]
# Previsão depois da função de ativação: [0.55765581 0.59379316 0.64765115 0.57754432 0.71192677 0.74645441]
# Erro do modelo: [ 0.55765581  0.59379316 -0.35234885  0.57754432 -0.28807323 -0.25354559]
# Valores de pesos: [0.12382576 0.05366349]
# Valor de bias: -0.025815612845788753
#
# Treinamento do Modelo na Iteração 27
# Previsão antes da função de ativação: [0.23216889 0.3828264  0.61397915 0.31266413 0.91529417 1.09278343]
# Previsão depois da função de ativação: [0.5577829  0.59455461 0.64884796 0.57753541 0.71408229 0.7489055 ]
# Erro do modelo: [ 0.5577829   0.59455461 -0.35115204  0.57753541 -0.28591771 -0.2510945 ]
# Valores de pesos: [0.12660107 0.05323127]
# Valor de bias: -0.02721846064669887
#
# Treinamento do Modelo na Iteração 28
# Previsão antes da função de ativação: [0.23246078 0.38567749 0.6187411  0.31230769 0.92517451 1.10500685]
# Previsão depois da função de ativação: [0.5578549  0.59524171 0.64993218 0.57744844 0.71609527 0.75119706]
# Erro do modelo: [ 0.5578549   0.59524171 -0.35006782  0.57744844 -0.28390473 -0.24880294]
# Valores de pesos: [0.129329   0.05273999]
# Valor de bias: -0.028631409924630268
#
# Treinamento do Modelo na Iteração 29
# Previsão antes da função de ativação: [0.23254756 0.38824656 0.62305554 0.31165755 0.93445353 1.11652252]
# Previsão depois da função de ativação: [0.5578763  0.59586052 0.65091316 0.5772898  0.71797794 0.75334311]
# Erro do modelo: [ 0.5578763   0.59586052 -0.34908684  0.5772898  -0.28202206 -0.24665689]
# Valores de pesos: [0.13201304 0.05219454]
# Valor de bias: -0.030053511317977035
#
# Treinamento do Modelo na Iteração 30
# Previsão antes da função de ativação: [0.23244589 0.39055621 0.62695834 0.31073771 0.94317897 1.12738656]
# Previsão depois da função de ativação: [0.55785123 0.59641659 0.65179946 0.57706532 0.71974135 0.75535628]
# Erro do modelo: [ 0.55785123  0.59641659 -0.34820054  0.57706532 -0.28025865 -0.24464372]
# Valores de pesos: [0.13465639 0.05159941]
# Valor de bias: -0.0314838950021067
#
# Treinamento do Modelo na Iteração 31
# Previsão antes da função de ativação: [0.23217103 0.39262712 0.63048234 0.30957015 0.95139453 1.13765034]
# Previsão depois da função de ativação: [0.55778343 0.59691497 0.65259882 0.57678034 0.72139554 0.75724798]
# Erro do modelo: [ 0.55778343  0.59691497 -0.34740118  0.57678034 -0.27860446 -0.24275202]
# Valores de pesos: [0.13726196 0.0509587 ]
# Valor de bias: -0.032921763460109395
#
# Treinamento do Modelo na Iteração 32
# Previsão antes da função de ativação: [0.23173695 0.39447826 0.63365763 0.308175   0.95914025 1.14736092]
# Previsão depois da função de ativação: [0.55767636 0.59736028 0.65331835 0.57643974 0.72294964 0.75902855]
# Erro do modelo: [ 0.55767636  0.59736028 -0.34668165  0.57643974 -0.27705036 -0.24097145]
# Valores de pesos: [0.13983244 0.05027617]
# Valor de bias: -0.03436638498697461
#
# Treinamento do Modelo na Iteração 33
# Previsão antes da função de ativação: [0.23115648 0.396127   0.63651178 0.30657073 0.96645284 1.15656145]
# Previsão depois da função de ativação: [0.55753316 0.59775678 0.65396452 0.57604799 0.72441191 0.76070735]
# Erro do modelo: [ 0.55753316  0.59775678 -0.34603548  0.57604799 -0.27558809 -0.23929265]
# Valores de pesos: [0.14237029 0.04955527]
# Valor de bias: -0.035817087843435166
#
# Treinamento do Modelo na Iteração 34
# Previsão antes da função de ativação: [0.23044137 0.39758929 0.63907011 0.30477427 0.97336596 1.16529152]
# Previsão depois da função de ativação: [0.55735675 0.59810832 0.65454323 0.57560921 0.7257899  0.76229288]
# Erro do modelo: [ 0.55735675  0.59810832 -0.34545677  0.57560921 -0.2742101  -0.23770712]
# Valores de pesos: [0.14487776 0.04879917]
# Valor de bias: -0.03727325498632471
#
# Treinamento do Modelo na Iteração 35
# Previsão antes da função de ativação: [0.22960242 0.39887976 0.64135586 0.30280117 0.97991054 1.17358747]
# Previsão depois da função de ativação: [0.55714976 0.59841848 0.65505989 0.57512714 0.72709047 0.76379285]
# Erro do modelo: [ 0.55714976  0.59841848 -0.34494011  0.57512714 -0.27290953 -0.23620715]
# Valores de pesos: [0.14735692 0.04801078]
# Valor de bias: -0.038734319311461624
#
# Treinamento do Modelo na Iteração 36
# Previsão antes da função de ativação: [0.22864956 0.40001187 0.64339035 0.30066573 0.98611498 1.18148268]
# Previsão depois da função de ativação: [0.55691464 0.59869051 0.65551945 0.57460525 0.72831988 0.76521429]
# Erro do modelo: [ 0.55691464  0.59869051 -0.34448055  0.57460525 -0.27168012 -0.23478571]
# Valores de pesos: [0.14980968 0.04719279]
# Valor de bias: -0.040199759352998646
#
# Treinamento do Modelo na Iteração 37
# Previsão antes da função de ativação: [0.22759189 0.40099797 0.64519323 0.29838108 0.99200538 1.18900785]
# Previsão depois da função de ativação: [0.55665364 0.59892741 0.65592645 0.57404671 0.72948384 0.76656357]
# Erro do modelo: [ 0.55665364  0.59892741 -0.34407355  0.57404671 -0.27051616 -0.23343643]
# Valores de pesos: [0.15223779 0.04634765]
# Valor de bias: -0.04166909539003775
#
# Treinamento do Modelo na Iteração 38
# Previsão antes da função de ativação: [0.22643782 0.40184943 0.64678252 0.29595929 0.99760575 1.19619119]
# Previsão depois da função de ativação: [0.55636881 0.59913192 0.65628505 0.57345444 0.73058758 0.76784652]
# Erro do modelo: [ 0.55636881  0.59913192 -0.34371495  0.57345444 -0.26941242 -0.23215348]
# Valores de pesos: [0.15464286 0.04547763]
# Valor de bias: -0.0431418859172539
#
# Treinamento do Modelo na Iteração 39
# Previsão antes da função de ativação: [0.22519505 0.40257672 0.64817484 0.29341149 1.00293818 1.20305866]
# Previsão depois da função de ativação: [0.55606204 0.59930659 0.65659905 0.57283112 0.73163587 0.76906846]
# Erro do modelo: [ 0.55606204  0.59930659 -0.34340095  0.57283112 -0.26836413 -0.23093154]
# Valores de pesos: [0.15702637 0.04458482]
# Valor de bias: -0.04461772444142811
#
# Treinamento do Modelo na Iteração 40
# Previsão antes da função de ativação: [0.22387068 0.40318946 0.64938545 0.29074791 1.008023   1.20963419]
# Previsão depois da função de ativação: [0.55573509 0.59945372 0.65687196 0.57217922 0.73263307 0.77023422]
# Erro do modelo: [ 0.55573509  0.59945372 -0.34312804  0.57217922 -0.26736693 -0.22976578]
# Valores de pesos: [0.15938969 0.04367113]
# Valor de bias: -0.04609623657027019
#
# Treinamento do Modelo na Iteração 41
# Previsão antes da função de ativação: [0.22247127 0.40369652 0.65042845 0.28797796 1.01287895 1.21593977]
# Previsão depois da função de ativação: [0.55538955 0.59957546 0.65710701 0.57150103 0.73358319 0.77134823]
# Erro do modelo: [ 0.55538955  0.59957546 -0.34289299  0.57150103 -0.26641681 -0.22865177]
# Valores de pesos: [0.16173407 0.04273833]
# Valor de bias: -0.047577077363810207
#
# Treinamento do Modelo na Iteração 42
# Previsão antes da função de ativação: [0.22100283 0.40410607 0.65131681 0.28511033 1.01752329 1.22199569]
# Previsão depois da função de ativação: [0.55502692 0.59967379 0.65730714 0.57079864 0.73448988 0.77241456]
# Erro do modelo: [ 0.55502692  0.59967379 -0.34269286  0.57079864 -0.26551012 -0.22758544]
# Valores de pesos: [0.16406069 0.04178807]
# Valor de bias: -0.04905992892203463
#
# Treinamento do Modelo na Iteração 43
# Previsão antes da função de ativação: [0.21947092 0.40442564 0.65206246 0.28215302 1.0219719  1.22782066]
# Previsão depois da função de ativação: [0.55464855 0.5997505  0.65747508 0.57007399 0.73535652 0.77343691]
# Erro do modelo: [ 0.55464855  0.5997505  -0.34252492  0.57007399 -0.26464348 -0.22656309]
# Valores de pesos: [0.1663706  0.04082183]
# Valor de bias: -0.05054449818540978
#
# Treinamento do Modelo na Iteração 44
# Previsão antes da função de ativação: [0.21788068 0.40466219 0.65267645 0.27911342 1.02623948 1.23343191]
# Previsão depois da função de ativação: [0.5542557  0.59980728 0.65761334 0.56932885 0.73618619 0.77441867]
# Erro do modelo: [ 0.5542557   0.59980728 -0.34238666  0.56932885 -0.26381381 -0.22558133]
# Valores de pesos: [0.1686648  0.03984101]
# Valor de bias: -0.052030514927528596
#
# Treinamento do Modelo na Iteração 45
# Previsão antes da função de ativação: [0.21623681 0.40482211 0.65316893 0.27599833 1.03033953 1.23884534]
# Previsão depois da função de ativação: [0.55384954 0.59984567 0.65772422 0.56856489 0.73698172 0.77536296]
# Erro do modelo: [ 0.55384954  0.59984567 -0.34227578  0.56856489 -0.26301828 -0.22463704]
# Valores de pesos: [0.17094419 0.03884689]
# Valor de bias: -0.05351772992138971
#
# Treinamento do Modelo na Iteração 46
# Previsão antes da função de ativação: [0.21454368 0.40491132 0.65354928 0.27281402 1.03428455 1.24407563]
# Previsão depois da função de ativação: [0.55343113 0.59986708 0.65780984 0.56778361 0.7377457  0.77627264]
# Erro do modelo: [ 0.55343113  0.59986708 -0.34219016  0.56778361 -0.2622543  -0.22372736]
# Valores de pesos: [0.17320962 0.03784065]
# Valor de bias: -0.0550059132628121
#
# Treinamento do Modelo na Iteração 47
# Previsão antes da função de ativação: [0.21280532 0.40493526 0.65382618 0.2695663  1.03808606 1.24913632]
# Previsão depois da função de ativação: [0.55300146 0.59987283 0.65787216 0.56698643 0.73848054 0.77715032]
# Erro do modelo: [ 0.55300146  0.59987283 -0.34212784  0.56698643 -0.26151946 -0.22284968]
# Valores de pesos: [0.17546186 0.03682337]
# Valor de bias: -0.05649485283624271
#
# Treinamento do Modelo na Iteração 48
# Previsão antes da função de ativação: [0.21102544 0.40489899 0.6540076  0.2662605  1.04175469 1.25403992]
# Previsão depois da função de ativação: [0.55256145 0.59986412 0.657913   0.56617463 0.73918843 0.77799841]
# Erro do modelo: [ 0.55256145  0.59986412 -0.342087    0.56617463 -0.26081157 -0.22200159]
# Valores de pesos: [0.17770163 0.03579608]
# Valor de bias: -0.05798435290975925
#
# Treinamento do Modelo na Iteração 49
# Previsão antes da função de ativação: [0.20920747 0.40480714 0.65410092 0.26290158 1.04530026 1.25879797]
# Previsão depois da função de ativação: [0.55211194 0.59984208 0.657934   0.56534943 0.7398714  0.77881912]
# Erro do modelo: [ 0.55211194  0.59984208 -0.342066    0.56534943 -0.2601286  -0.22118088]
# Valores de pesos: [0.1799296  0.03475968]
# Valor de bias: -0.05947423284743413
#
# Treinamento do Modelo na Iteração 50
# Previsão antes da função de ativação: [0.20735457 0.40466402 0.65411298 0.2594941  1.04873186 1.26342115]
# Previsão depois da função de ativação: [0.5516537  0.59980772 0.65793671 0.56451193 0.74053131 0.77961448]
# Erro do modelo: [ 0.5516537   0.59980772 -0.34206329  0.56451193 -0.25946869 -0.22038552]
# Valores de pesos: [0.18214638 0.03371505]
# Valor de bias: -0.06096432592843103
#
# Treinamento do Modelo na Iteração 51
# Previsão antes da função de ativação: [0.20546968 0.40447358 0.65405007 0.25604226 1.05205787 1.2679193 ]
# Previsão depois da função de ativação: [0.55118746 0.59976201 0.65792255 0.56366314 0.74116987 0.78038636]
# Erro do modelo: [ 0.55118746  0.59976201 -0.34207745  0.56366314 -0.25883013 -0.21961364]
# Valores de pesos: [0.18435253 0.03266298]
# Valor de bias: -0.062454478263273494
#
# Treinamento do Modelo na Iteração 52
# Previsão antes da função de ativação: [0.2035555  0.40423951 0.653918   0.25254997 1.05528603 1.27230154]
# Previsão depois da função de ativação: [0.55071389 0.59970582 0.65789283 0.56280404 0.74178867 0.78113648]
# Erro do modelo: [ 0.55071389  0.59970582 -0.34210717  0.56280404 -0.25821133 -0.21886352]
# Valores de pesos: [0.18654858 0.0316042 ]
# Valor de bias: -0.06394454779867274
#
# Treinamento do Modelo na Iteração 53
# Previsão antes da função de ativação: [0.20161452 0.40396519 0.65372216 0.24902082 1.05842351 1.27657628]
# Previsão depois da função de ativação: [0.55023359 0.59963997 0.65784875 0.56193548 0.74238916 0.78186642]
# Erro do modelo: [ 0.55023359  0.59963997 -0.34215125  0.56193548 -0.25761084 -0.21813358]
# Valores de pesos: [0.18873501 0.03053938]
# Valor de bias: -0.06543440340314423
#
# Treinamento do Modelo na Iteração 54
# Previsão antes da função de ativação: [0.19964906 0.40365376 0.65346753 0.24545813 1.06147693 1.28075132]
# Previsão depois da função de ativação: [0.54974713 0.5995652  0.65779144 0.56105828 0.74297269 0.78257764]
# Erro do modelo: [ 0.54974713  0.5995652  -0.34220856  0.56105828 -0.25702731 -0.21742236]
# Valores de pesos: [0.19091228 0.02946916]
# Valor de bias: -0.0669239240263928
#
# Treinamento do Modelo na Iteração 55
# Previsão antes da função de ativação: [0.19766125 0.40330811 0.6531587  0.24186499 1.06445242 1.28483385]
# Previsão depois da função de ativação: [0.54925505 0.59948221 0.65772192 0.5601732  0.74354049 0.78327148]
# Erro do modelo: [ 0.54925505  0.59948221 -0.34227808  0.5601732  -0.25645951 -0.21672852]
# Valores de pesos: [0.19308079 0.02839411]
# Valor de bias: -0.06841299792611545
#
# Treinamento do Modelo na Iteração 56
# Previsão antes da função de ativação: [0.19565307 0.40293092 0.65279993 0.23824423 1.06735563 1.28883053]
# Previsão depois da função de ativação: [0.54875783 0.59939164 0.65764114 0.55928092 0.7440937  0.78394918]
# Erro do modelo: [ 0.54875783  0.59939164 -0.34235886  0.55928092 -0.2559063  -0.21605082]
# Valores de pesos: [0.19524095 0.02731477]
# Valor de bias: -0.06990152195646897
#
# Treinamento do Modelo na Iteração 57
# Previsão antes da função de ativação: [0.19362634 0.40252467 0.65239515 0.23459849 1.07019181 1.29274752]
# Previsão depois da função de ativação: [0.54825592 0.59929409 0.65755    0.55838211 0.74463339 0.78461187]
# Erro do modelo: [ 0.54825592  0.59929409 -0.34245     0.55838211 -0.25536661 -0.21538813]
# Valores de pesos: [0.19739309 0.02623163]
# Valor de bias: -0.07138940091298472
#
# Treinamento do Modelo na Iteração 58
# Previsão antes da função de ativação: [0.19158276 0.40209166 0.651948   0.2309302  1.0729658  1.29659052]
# Previsão depois da função de ativação: [0.54774973 0.5991901  0.65744931 0.55747734 0.74516052 0.78526061]
# Erro do modelo: [ 0.54774973  0.5991901  -0.34255069  0.55747734 -0.25483948 -0.21473939]
# Valores de pesos: [0.19953755 0.02514515]
# Valor de bias: -0.07287654692919297
#
# Treinamento do Modelo na Iteração 59
# Previsão antes da função de ativação: [0.18952387 0.401634   0.65146185 0.22724159 1.0756821  1.3003648 ]
# Previsão depois da função de ativação: [0.54723965 0.59908018 0.65733981 0.55656719 0.74567599 0.78589637]
# Erro do modelo: [ 0.54723965  0.59908018 -0.34266019  0.55656719 -0.25432401 -0.21410363]
# Valores de pesos: [0.20167464 0.02405575]
# Valor de bias: -0.07436287892064987
#
# Treinamento do Modelo na Iteração 60
# Previsão antes da função de ativação: [0.18745114 0.40115366 0.65093981 0.22353477 1.07834485 1.30407524]
# Previsão depois da função de ativação: [0.54672604 0.59896481 0.65722221 0.55565215 0.74618063 0.78652004]
# Erro do modelo: [ 0.54672604  0.59896481 -0.34277779  0.55565215 -0.25381937 -0.21347996]
# Valores de pesos: [0.20380465 0.02296383]
# Valor de bias: -0.07584832207244789
#
# Treinamento do Modelo na Iteração 61
# Previsão antes da função de ativação: [0.1853659  0.40065246 0.65038476 0.21981164 1.08095789 1.30772637]
# Previsão depois da função de ativação: [0.54620924 0.59884441 0.65709716 0.55473271 0.74667521 0.78713245]
# Erro do modelo: [ 0.54620924  0.59884441 -0.34290284  0.55473271 -0.25332479 -0.21286755]
# Valores de pesos: [0.20592783 0.02186974]
# Valor de bias: -0.07733280736663918
#
# Treinamento do Modelo na Iteração 62
# Previsão antes da função de ativação: [0.18326938 0.40013207 0.64979939 0.21607399 1.08352478 1.31132235]
# Previsão depois da função de ativação: [0.54568953 0.59871939 0.65696525 0.55380931 0.74716044 0.78773435]
# Erro do modelo: [ 0.54568953  0.59871939 -0.34303475  0.55380931 -0.25283956 -0.21226565]
# Valores de pesos: [0.20804442 0.02077383]
# Valor de bias: -0.07881627114631636
#
# Treinamento do Modelo na Iteração 63
# Previsão antes da função de ativação: [0.18116272 0.39959406 0.64918614 0.21232347 1.08604882 1.31486707]
# Previsão depois da função de ativação: [0.54516722 0.59859013 0.65682704 0.55288235 0.74763696 0.78832645]
# Erro do modelo: [ 0.54516722  0.59859013 -0.34317296  0.55288235 -0.25236304 -0.21167355]
# Valores de pesos: [0.21015467 0.0196764 ]
# Valor de bias: -0.08029865471337926
#
# Treinamento do Modelo na Iteração 64
# Previsão antes da função de ativação: [0.179047   0.39903986 0.64854732 0.20856159 1.08853305 1.31836411]
# Previsão depois da função de ativação: [0.54464255 0.59845696 0.65668303 0.55195222 0.74810538 0.78890941]
# Erro do modelo: [ 0.54464255  0.59845696 -0.34331697  0.55195222 -0.25189462 -0.21109059]
# Valores de pesos: [0.21225876 0.01857773]
# Valor de bias: -0.08177990395727328
#
# Treinamento do Modelo na Iteração 65
# Previsão antes da função de ativação: [0.17692318 0.39847081 0.64788504 0.20478978 1.0909803  1.32181679]
# Previsão depois da função de ativação: [0.54411578 0.5983202  0.6565337  0.55101926 0.74856627 0.78948381]
# Erro do modelo: [ 0.54411578  0.5983202  -0.3434663   0.55101926 -0.25143373 -0.21051619]
# Valores de pesos: [0.21435691 0.0174781 ]
# Valor de bias: -0.08325996901221772
#
# Treinamento do Modelo na Iteração 66
# Previsão antes da função de ativação: [0.17479218 0.39788815 0.64720125 0.20100933 1.09339317 1.32522818]
# Previsão depois da função de ativação: [0.54358713 0.59818016 0.65637949 0.55008381 0.74902014 0.79005023]
# Erro do modelo: [ 0.54358713  0.59818016 -0.34362051  0.55008381 -0.25097986 -0.20994977]
# Valores de pesos: [0.21644929 0.01637774]
# Valor de bias: -0.08473880394065339
#
# Treinamento do Modelo na Iteração 67
# Previsão antes da função de ativação: [0.17265484 0.397293   0.64649778 0.19722145 1.09577411 1.32860114]
# Previsão depois da função de ativação: [0.5430568  0.5980371  0.65622081 0.54914617 0.74946746 0.79060915]
# Erro do modelo: [ 0.5430568   0.5980371  -0.34377919  0.54914617 -0.25053254 -0.20939085]
# Valores de pesos: [0.21853607 0.01527689]
# Valor de bias: -0.08621636644083049
#
# Treinamento do Modelo na Iteração 68
# Previsão antes da função de ativação: [0.17051193 0.39668645 0.6457763  0.19342726 1.09812534 1.3319383 ]
# Previsão depois da função de ativação: [0.542525   0.59789128 0.65605803 0.54820661 0.74990869 0.79116107]
# Erro do modelo: [ 0.542525    0.59789128 -0.34394197  0.54820661 -0.25009131 -0.20883893]
# Valores de pesos: [0.22061741 0.01417575]
# Valor de bias: -0.08769261757663144
#
# Treinamento do Modelo na Iteração 69
# Previsão antes da função de ativação: [0.16836417 0.39606946 0.64503837 0.1896278  1.10044894 1.3352421 ]
# Previsão depois da função de ativação: [0.5419919  0.59774294 0.6558915  0.5472654  0.75034421 0.79170642]
# Erro do modelo: [ 0.5419919   0.59774294 -0.3441085   0.5472654  -0.24965579 -0.20829358]
# Valores de pesos: [0.22269345 0.01307452]
# Valor de bias: -0.08916752152788196
#
# Treinamento do Modelo na Iteração 70
# Previsão antes da função de ativação: [0.16621223 0.39544294 0.64428543 0.18582401 1.10274685 1.33851482]
# Previsão depois da função de ativação: [0.54145766 0.59759229 0.65572154 0.54632278 0.75077443 0.7922456 ]
# Erro do modelo: [ 0.54145766  0.59759229 -0.34427846  0.54632278 -0.24922557 -0.2077544 ]
# Valores de pesos: [0.22476432 0.01197338]
# Valor de bias: -0.09064104535954755
#
# Treinamento do Modelo na Iteração 71
# Previsão antes da função de ativação: [0.16405672 0.39480774 0.64351882 0.18201679 1.10502084 1.34175854]
# Previsão depois da função de ativação: [0.54092244 0.59743953 0.65554846 0.54537898 0.75119968 0.79277898]
# Erro do modelo: [ 0.54092244  0.59743953 -0.34445154  0.54537898 -0.24880032 -0.20722102]
# Valores de pesos: [0.22683016 0.01087249]
# Valor de bias: -0.09211315880834403
#
# Treinamento do Modelo na Iteração 72
# Previsão antes da função de ativação: [0.16189822 0.39416463 0.64273976 0.17820696 1.10727257 1.34497522]
# Previsão depois da função de ativação: [0.54038638 0.59728485 0.65537253 0.54443421 0.75162028 0.79330692]
# Erro do modelo: [ 0.54038638  0.59728485 -0.34462747  0.54443421 -0.24837972 -0.20669308]
# Valores de pesos: [0.22889107 0.00977201]
# Valor de bias: -0.09358383408541059
#
# Treinamento do Modelo na Iteração 73
# Previsão antes da função de ativação: [0.15973725 0.39351433 0.64194942 0.17439526 1.10950357 1.34816665]
# Previsão depois da função de ativação: [0.53984962 0.59712842 0.655194   0.54348865 0.75203655 0.79382974]
# Erro do modelo: [ 0.53984962  0.59712842 -0.344806    0.54348865 -0.24796345 -0.20617026]
# Valores de pesos: [0.23094718 0.00867207]
# Valor de bias: -0.09505304569380314
#
# Treinamento do Modelo na Iteração 74
# Previsão antes da função de ativação: [0.15757431 0.39285752 0.64114884 0.17058241 1.11171526 1.35133451]
# Previsão depois da função de ativação: [0.53931227 0.5969704  0.65501311 0.54254249 0.75244875 0.79434772]
# Erro do modelo: [ 0.53931227  0.5969704  -0.34498689  0.54254249 -0.24755125 -0.20565228]
# Valores de pesos: [0.23299857 0.00757281]
# Valor de bias: -0.09652077025966595
#
# Treinamento do Modelo na Iteração 75
# Previsão antes da função de ativação: [0.15540983 0.39219481 0.640339   0.16676905 1.11390896 1.35448034]
# Previsão depois da função de ativação: [0.53877445 0.59681094 0.65483009 0.5415959  0.75285714 0.79486114]
# Erro do modelo: [ 0.53877445  0.59681094 -0.34516991  0.5415959  -0.24714286 -0.20513886]
# Valores de pesos: [0.23504534 0.00647436]
# Valor de bias: -0.09798698637603065
#
# Treinamento do Modelo na Iteração 76
# Previsão antes da função de ativação: [0.15324425 0.39152677 0.63952083 0.16295579 1.11608588 1.35760558]
# Previsão depois da função de ativação: [0.53823626 0.59665018 0.65464514 0.54064903 0.75326196 0.79537027]
# Erro do modelo: [ 0.53823626  0.59665018 -0.34535486  0.54064903 -0.24673804 -0.20462973]
# Valores de pesos: [0.23708759 0.00537681]
# Valor de bias: -0.09945167445827585
#
# Treinamento do Modelo na Iteração 77
# Previsão antes da função de ativação: [0.15107795 0.39085394 0.63869516 0.15914317 1.11824715 1.36071155]
# Previsão depois da função de ativação: [0.53769781 0.59648825 0.65445844 0.53970203 0.75366344 0.79587532]
# Erro do modelo: [ 0.53769781  0.59648825 -0.34554156  0.53970203 -0.24633656 -0.20412468]
# Valores de pesos: [0.23912539 0.00428028]
# Valor de bias: -0.10091481661035677
#
# Treinamento do Modelo na Iteração 78
# Previsão antes da função de ativação: [0.14891128 0.39017681 0.63786277 0.15533171 1.12039383 1.3637995 ]
# Previsão depois da função de ativação: [0.53715918 0.59632526 0.65427018 0.53875503 0.75406176 0.79637652]
# Erro do modelo: [ 0.53715918  0.59632526 -0.34572982  0.53875503 -0.24593824 -0.20362348]
# Valores de pesos: [0.24115882 0.00318487]
# Valor de bias: -0.10237639650098491
#
# Treinamento do Modelo na Iteração 79
# Previsão antes da função de ativação: [0.14674458 0.38949583 0.63702438 0.15152188 1.12252688 1.36687056]
# Previsão depois da função de ativação: [0.53662045 0.59616133 0.65408051 0.53780816 0.75445713 0.79687407]
# Erro do modelo: [ 0.53662045  0.59616133 -0.34591949  0.53780816 -0.24554287 -0.20312593]
# Valores de pesos: [0.24318795 0.00209065]
# Valor de bias: -0.10383639924900209
#
# Treinamento do Modelo na Iteração 80
# Previsão antes da função de ativação: [0.14457816 0.38881143 0.63618067 0.14771413 1.1246472  1.36992579]
# Previsão depois da função de ativação: [0.53608171 0.59599654 0.65388959 0.53686153 0.75484971 0.79736816]
# Erro do modelo: [ 0.53608171  0.59599654 -0.34611041  0.53686153 -0.24515029 -0.20263184]
# Valores de pesos: [0.24521284 0.00099771]
# Valor de bias: -0.10529481131725227
#
# Treinamento do Modelo na Iteração 81
# Previsão antes da função de ativação: [0.1424123  0.38812399 0.63533225 0.14390886 1.12675563 1.37296618]
# Previsão depois da função de ativação: [0.53554302 0.59583101 0.65369755 0.53591525 0.75523967 0.79785896]
# Erro do modelo: [ 0.53554302  0.59583101 -0.34630245  0.53591525 -0.24476033 -0.20214104]
# Valores de pesos: [ 2.47233566e-01 -9.38765035e-05]
# Valor de bias: -0.10675162041430893
#
# Treinamento do Modelo na Iteração 82
# Previsão antes da função de ativação: [0.14024725 0.38743388 0.63447969 0.14010644 1.12885295 1.37599264]
# Previsão depois da função de ativação: [0.53500446 0.59566481 0.65350452 0.53496942 0.75562715 0.79834663]
# Erro do modelo: [ 0.53500446  0.59566481 -0.34649548  0.53496942 -0.24437285 -0.20165337]
# Valores de pesos: [ 0.24925018 -0.00118404]
# Valor de bias: -0.10820681540346565
#
# Treinamento do Modelo na Iteração 83
# Previsão antes da função de ativação: [0.13808327 0.38674144 0.63362354 0.13630722 1.13093986 1.37900601]
# Previsão depois da função de ativação: [0.53446607 0.59549802 0.65331063 0.53402414 0.75601231 0.79883131]
# Erro do modelo: [ 0.53446607  0.59549802 -0.34668937  0.53402414 -0.24398769 -0.20116869]
# Valores de pesos: [ 0.25126273 -0.00227271]
# Valor de bias: -0.10966038621844329
#
# Treinamento do Modelo na Iteração 84
# Previsão antes da função de ativação: [0.13592058 0.38604696 0.63276428 0.13251153 1.13301704 1.38200707]
# Previsão depois da função de ativação: [0.53392793 0.59533072 0.65311599 0.53307949 0.75639525 0.79931315]
# Erro do modelo: [ 0.53392793  0.59533072 -0.34688401  0.53307949 -0.24360475 -0.20068685]
# Valores de pesos: [ 0.25327128 -0.00335983]
# Valor de bias: -0.11111232378530944
#
# Treinamento do Modelo na Iteração 85
# Previsão antes da função de ativação: [0.13375939 0.38535075 0.63190237 0.12871964 1.1350851  1.38499655]
# Previsão depois da função de ativação: [0.53339008 0.59516299 0.65292069 0.53213555 0.75677612 0.79979227]
# Erro do modelo: [ 0.53339008  0.59516299 -0.34707931  0.53213555 -0.24322388 -0.20020773]
# Valores de pesos: [ 0.25527587 -0.00444535]
# Valor de bias: -0.1125626199501445
#
# Treinamento do Modelo na Iteração 86
# Previsão antes da função de ativação: [0.13159987 0.38465307 0.63103823 0.12493185 1.13714462 1.38797513]
# Previsão depois da função de ativação: [0.53285257 0.59499487 0.65272484 0.5311924  0.757155   0.80026879]
# Erro do modelo: [ 0.53285257  0.59499487 -0.34727516  0.5311924  -0.242845   -0.19973121]
# Valores de pesos: [ 0.25727654 -0.00552922]
# Valor de bias: -0.11401126741202451
#
# Treinamento do Modelo na Iteração 87
# Previsão antes da função de ativação: [0.12944223 0.38395415 0.63017226 0.1211484  1.13919611 1.39094343]
# Previsão depois da função de ativação: [0.53231545 0.59482644 0.65252852 0.53025011 0.75753201 0.80074281]
# Erro do modelo: [ 0.53231545  0.59482644 -0.34747148  0.53025011 -0.24246799 -0.19925719]
# Valores de pesos: [ 0.25927334 -0.00661139]
# Valor de bias: -0.11545825966092373
#
# Treinamento do Modelo na Iteração 88
# Previsão antes da função de ativação: [0.1272866  0.38325425 0.6293048  0.11736952 1.14124009 1.39390203]
# Previsão depois da função de ativação: [0.53177876 0.59465775 0.65233181 0.52930874 0.75790725 0.80121445]
# Erro do modelo: [ 0.53177876  0.59465775 -0.34766819  0.52930874 -0.24209275 -0.19878555]
# Valores de pesos: [ 0.2612663  -0.00769182]
# Valor de bias: -0.11690359092016994
#
# Treinamento do Modelo na Iteração 89
# Previsão antes da função de ativação: [0.12513316 0.38255355 0.62843621 0.11359543 1.14327699 1.39685147]
# Previsão depois da função de ativação: [0.53124253 0.59448884 0.65213479 0.52836836 0.75828079 0.80168379]
# Erro do modelo: [ 0.53124253  0.59448884 -0.34786521  0.52836836 -0.24171921 -0.19831621]
# Valores de pesos: [ 0.26325547 -0.00877047]
# Valor de bias: -0.11834725609311403
#
# Treinamento do Modelo na Iteração 90
# Previsão antes da função de ativação: [0.12298203 0.38185226 0.62756678 0.10982632 1.14530725 1.39979224]
# Previsão depois da função de ativação: [0.53070681 0.59431977 0.65193753 0.52742902 0.75865272 0.80215092]
# Erro do modelo: [ 0.53070681  0.59431977 -0.34806247  0.52742902 -0.24134728 -0.19784908]
# Valores de pesos: [ 0.26524087 -0.00984731]
# Valor de bias: -0.11978925071370024
#
# Treinamento do Modelo na Iteração 91
# Previsão antes da função de ativação: [0.12083335 0.38115056 0.62669681 0.10606238 1.14733125 1.40272481]
# Previsão depois da função de ativação: [0.53017163 0.59415057 0.6517401  0.52649077 0.75902312 0.80261592]
# Erro do modelo: [ 0.53017163  0.59415057 -0.3482599   0.52649077 -0.24097688 -0.19738408]
# Valores de pesos: [ 0.26722255 -0.0109223 ]
# Valor de bias: -0.12122957090064788
#
# Treinamento do Modelo na Iteração 92
# Previsão antes da função de ativação: [0.11868722 0.38044862 0.62582656 0.10230377 1.14934936 1.4056496 ]
# Previsão depois da função de ativação: [0.52963702 0.5939813  0.65154255 0.52555366 0.75939205 0.80307886]
# Erro do modelo: [ 0.52963702  0.5939813  -0.34845745  0.52555366 -0.24060795 -0.19692114]
# Valores de pesos: [ 0.26920052 -0.01199542]
# Valor de bias: -0.12266821331497685
#
# Treinamento do Modelo na Iteração 93
# Previsão antes da função de ativação: [0.11654377 0.37974659 0.62495628 0.09855065 1.15136191 1.40856702]
# Previsão depois da função de ativação: [0.52910301 0.59381198 0.65134494 0.52461774 0.75975959 0.80353983]
# Erro do modelo: [ 0.52910301  0.59381198 -0.34865506  0.52461774 -0.24024041 -0.19646017]
# Valores de pesos: [ 0.27117483 -0.01306662]
# Valor de bias: -0.12410517512062941
#
# Treinamento do Modelo na Iteração 94
# Previsão antes da função de ativação: [0.11440309 0.37904461 0.62408619 0.09480316 1.15336923 1.41147743]
# Previsão depois da função de ativação: [0.52856962 0.59364265 0.65114732 0.52368305 0.76012578 0.80399887]
# Erro do modelo: [ 0.52856962  0.59364265 -0.34885268  0.52368305 -0.23987422 -0.19600113]
# Valores de pesos: [ 0.27314549 -0.0141359 ]
# Valor de bias: -0.12554045394795957
#
# Treinamento do Modelo na Iteração 95
# Previsão antes da função de ativação: [0.11226528 0.37834282 0.62321651 0.09106142 1.15537159 1.41438118]
# Previsão depois da função de ativação: [0.52803688 0.59347335 0.65094974 0.52274964 0.76049069 0.80445605]
# Erro do modelo: [ 0.52803688  0.59347335 -0.34905026  0.52274964 -0.23950931 -0.19554395]
# Valores de pesos: [ 0.27511254 -0.01520323]
# Valor de bias: -0.12697404785987834
#
# Treinamento do Modelo na Iteração 96
# Previsão antes da função de ativação: [0.11013042 0.37764134 0.62234742 0.08732557 1.15736927 1.41727857]
# Previsão depois da função de ativação: [0.52750481 0.5933041  0.65075224 0.52181753 0.76085437 0.80491143]
# Erro do modelo: [ 0.52750481  0.5933041  -0.34924776  0.52181753 -0.23914563 -0.19508857]
# Valores de pesos: [ 0.27707599 -0.01626858]
# Valor de bias: -0.1284059553204591
#
# Treinamento do Modelo na Iteração 97
# Previsão antes da função de ativação: [0.10799858 0.37694028 0.62147911 0.0835957  1.15936251 1.42016992]
# Previsão depois da função de ativação: [0.52697343 0.59313492 0.65055487 0.52088676 0.76121686 0.80536505]
# Erro do modelo: [ 0.52697343  0.59313492 -0.34944513  0.52088676 -0.23878314 -0.19463495]
# Valores de pesos: [ 0.27903588 -0.01733194]
# Valor de bias: -0.12983617516582183
#
# Treinamento do Modelo na Iteração 98
# Previsão antes da função de ativação: [0.10586984 0.37623975 0.62061174 0.07987193 1.16135155 1.42305548]
# Previsão depois da função de ativação: [0.52644277 0.59296586 0.65035767 0.51995737 0.76157821 0.80581697]
# Erro do modelo: [ 0.52644277  0.59296586 -0.34964233  0.51995737 -0.23842179 -0.19418303]
# Valores de pesos: [ 0.28099221 -0.01839329]
# Valor de bias: -0.13126470657712888
#
# Treinamento do Modelo na Iteração 99
# Previsão antes da função de ativação: [0.10374427 0.37553984 0.61974546 0.07615433 1.1633366  1.42593552]
# Previsão depois da função de ativação: [0.52591283 0.59279692 0.65016066 0.51902939 0.76193846 0.80626723]
# Erro do modelo: [ 0.52591283  0.59279692 -0.34983934  0.51902939 -0.23806154 -0.19373277]
# Valores de pesos: [ 0.28294502 -0.01945262]
# Valor de bias: -0.13269154905553693
#
# Treinamento do Modelo na Iteração 100
# Previsão antes da função de ativação: [0.10162193 0.37484064 0.61888043 0.072443   1.16531786 1.42881026]
# Previsão depois da função de ativação: [0.52538364 0.59262813 0.64996388 0.51810283 0.76229765 0.80671587]
# Erro do modelo: [ 0.52538364  0.59262813 -0.35003612  0.51810283 -0.23770235 -0.19328413]
# Valores de pesos: [ 0.28489433 -0.0205099 ]
# Valor de bias: -0.1341167023989617
#
# Treinamento do Modelo na Iteração 101
# Previsão antes da função de ativação: [0.09950286 0.37414224 0.61801676 0.06873801 1.16729551 1.43167993]
# Previsão depois da função de ativação: [0.52485521 0.59245951 0.64976736 0.51717774 0.76265582 0.80716293]
# Erro do modelo: [ 0.52485521  0.59245951 -0.35023264  0.51717774 -0.23734418 -0.19283707]
# Valores de pesos: [ 0.28684014 -0.02156514]
# Valor de bias: -0.13554016668052243
#
# Treinamento do Modelo na Iteração 102
# Previsão antes da função de ativação: [0.09738713 0.37344471 0.61715458 0.06503943 1.16926973 1.43454473]
# Previsão depois da função de ativação: [0.52432756 0.59229108 0.64957112 0.51625413 0.76301299 0.80760845]
# Erro do modelo: [ 0.52432756  0.59229108 -0.35042888  0.51625413 -0.23698701 -0.19239155]
# Valores de pesos: [ 0.28878249 -0.02261831]
# Valor de bias: -0.1369619422285434
#
# Treinamento do Modelo na Iteração 103
# Previsão antes da função de ativação: [0.09527478 0.37274812 0.61629399 0.06134732 1.17124066 1.43740484]
# Previsão depois da função de ativação: [0.52380069 0.59212285 0.64937521 0.51533202 0.7633692  0.80805246]
# Erro do modelo: [ 0.52380069  0.59212285 -0.35062479  0.51533202 -0.2366308  -0.19194754]
# Valores de pesos: [ 0.29072138 -0.0236694 ]
# Valor de bias: -0.1383820296079982
#
# Treinamento do Modelo na Iteração 104
# Previsão antes da função de ativação: [0.09316585 0.37205253 0.61543511 0.05766175 1.17320847 1.44026045]
# Previsão depois da função de ativação: [0.52327463 0.59195485 0.64917962 0.51441144 0.76372447 0.80849498]
# Erro do modelo: [ 0.52327463  0.59195485 -0.35082038  0.51441144 -0.23627553 -0.19150502]
# Valores de pesos: [ 0.29265684 -0.02471841]
# Valor de bias: -0.13980042960329156
#
# Treinamento do Modelo na Iteração 105
# Previsão antes da função de ativação: [0.09106038 0.37135801 0.61457802 0.05398276 1.17517328 1.4431117 ]
# Previsão depois da função de ativação: [0.52274938 0.59178708 0.6489844  0.51349241 0.76407884 0.80893605]
# Erro do modelo: [ 0.52274938  0.59178708 -0.3510156   0.51349241 -0.23592116 -0.19106395]
# Valores de pesos: [ 0.29458887 -0.02576533]
# Valor de bias: -0.14121714320228126
#
# Treinamento do Modelo na Iteração 106
# Previsão antes da função de ativação: [0.0889584  0.3706646  0.61372281 0.0503104  1.17713522 1.44595875]
# Previsão depois da função de ativação: [0.52222494 0.59161956 0.64878956 0.51257495 0.76443232 0.8093757 ]
# Erro do modelo: [ 0.52222494  0.59161956 -0.35121044  0.51257495 -0.23556768 -0.1906243 ]
# Valores de pesos: [ 0.2965175  -0.02681015]
# Valor de bias: -0.14263217158144914
#
# Treinamento do Modelo na Iteração 107
# Previsão antes da função de ativação: [0.08685994 0.36997237 0.61286956 0.04664471 1.1790944  1.44880174]
# Previsão depois da função de ativação: [0.52170134 0.5914523  0.64859511 0.51165906 0.76478494 0.80981395]
# Erro do modelo: [ 0.52170134  0.5914523  -0.35140489  0.51165906 -0.23521506 -0.19018605]
# Valores de pesos: [ 0.29844273 -0.02785287]
# Valor de bias: -0.14404551609213806
#
# Treinamento do Modelo na Iteração 108
# Previsão antes da função de ativação: [0.08476505 0.36928135 0.61201834 0.04298574 1.18105094 1.4516408 ]
# Previsão depois da função de ativação: [0.52117858 0.59128531 0.64840108 0.51074478 0.76513671 0.81025083]
# Erro do modelo: [ 0.52117858  0.59128531 -0.35159892  0.51074478 -0.23486329 -0.18974917]
# Valores de pesos: [ 0.30036459 -0.02889347]
# Valor de bias: -0.14545717824777674
#
# Treinamento do Modelo na Iteração 109
# Previsão antes da função de ativação: [0.08267373 0.36859158 0.61116923 0.03933352 1.18300493 1.45447605]
# Previsão depois da função de ativação: [0.52065667 0.59111861 0.64820747 0.50983211 0.76548767 0.81068635]
# Erro do modelo: [ 0.52065667  0.59111861 -0.35179253  0.50983211 -0.23451233 -0.18931365]
# Valores de pesos: [ 0.30228308 -0.02993196]
# Valor de bias: -0.14686715971202102
#
# Treinamento do Modelo na Iteração 110
# Previsão antes da função de ativação: [0.08058602 0.36790312 0.61032227 0.03568807 1.18495647 1.45730759]
# Previsão depois da função de ativação: [0.52013561 0.5909522  0.64801431 0.50892107 0.76583782 0.81112053]
# Erro do modelo: [ 0.52013561  0.5909522  -0.35198569  0.50892107 -0.23416218 -0.18887947]
# Valores de pesos: [ 0.30419822 -0.03096833]
# Valor de bias: -0.14827546228774466
#
# Treinamento do Modelo na Iteração 111
# Previsão antes da função de ativação: [0.07850193 0.36721598 0.60947754 0.03204943 1.18690565 1.46013554]
# Previsão depois da função de ativação: [0.51961541 0.59078609 0.64782161 0.50801167 0.76618718 0.8115534 ]
# Erro do modelo: [ 0.51961541  0.59078609 -0.35217839  0.50801167 -0.23381282 -0.1884466 ]
# Valores de pesos: [ 0.30611002 -0.03200258]
# Valor de bias: -0.149682087906818
#
# Treinamento do Modelo na Iteração 112
# Previsão antes da função de ativação: [0.07642148 0.36653021 0.60863507 0.02841761 1.18885253 1.46295997]
# Previsão depois da função de ativação: [0.51909608 0.59062029 0.64762938 0.50710392 0.76653578 0.81198498]
# Erro do modelo: [ 0.51909608  0.59062029 -0.35237062  0.50710392 -0.23346422 -0.18801502]
# Valores de pesos: [ 0.30801849 -0.0330347 ]
# Valor de bias: -0.15108703862061768
#
# Treinamento do Modelo na Iteração 113
# Previsão antes da função de ativação: [0.0743447  0.36584584 0.60779492 0.02479264 1.1907972  1.46578099]
# Previsão depois da função de ativação: [0.51857762 0.59045481 0.64743763 0.50619784 0.76688361 0.81241527]
# Erro do modelo: [ 0.51857762  0.59045481 -0.35256237  0.50619784 -0.23311639 -0.18758473]
# Valores de pesos: [ 0.30992365 -0.0340647 ]
# Valor de bias: -0.15249031659121384
#
# Treinamento do Modelo na Iteração 114
# Previsão antes da função de ativação: [0.07227159 0.36516288 0.60695714 0.02117454 1.19273973 1.46859868]
# Previsão depois da função de ativação: [0.51806004 0.59028965 0.64724637 0.50529344 0.7672307  0.8128443 ]
# ...
# Erro do modelo: [ 0.28606359  0.5215348  -0.40372001  0.16637272 -0.0838206  -0.04069982]
# Valores de pesos: [ 1.23372926 -0.4648821 ]
# Valor de bias: -0.9867935330906745
#
# Treinamento do Modelo na Iteração 963
# Previsão antes da função de ativação: [-0.91526953  0.08601867  0.38998373 -1.61259269  2.39256014  3.1614073 ]
# Previsão depois da função de ativação: [0.28592274 0.52149142 0.59627878 0.16622896 0.91625821 0.95935586]
# Erro do modelo: [ 0.28592274  0.52149142 -0.40372122  0.16622896 -0.08374179 -0.04064414]
# Valores de pesos: [ 1.23436027 -0.46511316]
# Valor de bias: -0.9875360930455455
#
# Treinamento do Modelo na Iteração 964
# Previsão antes da função de ativação: [-0.91595872  0.08584497  0.38997892 -1.61362845  2.39358629  3.1628334 ]
# Previsão depois da função de ativação: [0.28578205 0.52144807 0.59627762 0.16608546 0.91633692 0.95941143]
# Erro do modelo: [ 0.28578205  0.52144807 -0.40372238  0.16608546 -0.08366308 -0.04058857]
# Valores de pesos: [ 1.23499068 -0.46534387]
# Valor de bias: -0.9882783289587526
#
# Treinamento do Modelo na Iteração 965
# Previsão antes da função de ativação: [-0.91664733  0.08567141  0.38997435 -1.61466315  2.39461184  3.16425865]
# Previsão depois da função de ativação: [0.28564152 0.52140476 0.59627652 0.1659422  0.91641551 0.95946689]
# Erro do modelo: [ 0.28564152  0.52140476 -0.40372348  0.1659422  -0.08358449 -0.04053311]
# Valores de pesos: [ 1.23562051 -0.46557426]
# Valor de bias: -0.9890202412939098
#
# Treinamento do Modelo na Iteração 966
# Previsão antes da função de ativação: [-0.91733538  0.08549801  0.38997    -1.61569677  2.39563677  3.16568302]
# Previsão depois da função de ativação: [0.28550114 0.52136149 0.59627548 0.16579919 0.91649398 0.95952225]
# Erro do modelo: [ 0.28550114  0.52136149 -0.40372452  0.16579919 -0.08350602 -0.04047775]
# Valores de pesos: [ 1.23624976 -0.46580431]
# Valor de bias: -0.9897618305136254
#
# Treinamento do Modelo na Iteração 967
# Previsão antes da função de ativação: [-0.91802285  0.08532475  0.38996589 -1.61672932  2.39666109  3.16710654]
# Previsão depois da função de ativação: [0.28536092 0.52131826 0.59627449 0.16565643 0.91657234 0.9595775 ]
# Erro do modelo: [ 0.28536092  0.52131826 -0.40372551  0.16565643 -0.08342766 -0.0404225 ]
# Valores de pesos: [ 1.23687842 -0.46603403]
# Valor de bias: -0.9905030970795051
#
# Treinamento do Modelo na Iteração 968
# Previsão antes da função de ativação: [-0.91870976  0.08515165  0.389962   -1.6177608   2.39768481  3.1685292 ]
# Previsão depois da função de ativação: [0.28522086 0.52127506 0.59627355 0.16551391 0.91665059 0.95963265]
# Erro do modelo: [ 0.28522086  0.52127506 -0.40372645  0.16551391 -0.08334941 -0.04036735]
# Valores de pesos: [ 1.23750649 -0.46626342]
# Valor de bias: -0.9912440414521543
#
# Treinamento do Modelo na Iteração 969
# Previsão antes da função de ativação: [-0.91939609  0.08497869  0.38995835 -1.61879122  2.39870792  3.16995099]
# Previsão depois da função de ativação: [0.28508096 0.5212319  0.59627267 0.16537164 0.91672872 0.95968769]
# Erro do modelo: [ 0.28508096  0.5212319  -0.40372733  0.16537164 -0.08327128 -0.04031231]
# Valores de pesos: [ 1.23813399 -0.46649248]
# Valor de bias: -0.9919846640911811
#
# Treinamento do Modelo na Iteração 970
# Previsão antes da função de ativação: [-0.92008187  0.08480588  0.38995492 -1.61982058  2.39973042  3.17137193]
# Previsão depois da função de ativação: [0.28494121 0.52118877 0.59627185 0.16522962 0.91680674 0.95974262]
# Erro do modelo: [ 0.28494121  0.52118877 -0.40372815  0.16522962 -0.08319326 -0.04025738]
# Valores de pesos: [ 1.2387609 -0.4667212]
# Valor de bias: -0.9927249654551993
#
# Treinamento do Modelo na Iteração 971
# Previsão antes da função de ativação: [-0.92076707  0.08463322  0.38995172 -1.62084888  2.40075231  3.17279201]
# Previsão depois da função de ativação: [0.28480162 0.52114569 0.59627108 0.16508783 0.91688465 0.95979746]
# Erro do modelo: [ 0.28480162  0.52114569 -0.40372892  0.16508783 -0.08311535 -0.04020254]
# Valores de pesos: [ 1.23938723 -0.4669496 ]
# Valor de bias: -0.9934649460018304
#
# Treinamento do Modelo na Iteração 972
# Previsão antes da função de ativação: [-0.92145172  0.08446071  0.38994874 -1.62187611  2.4017736   3.17421123]
# Previsão depois da função de ativação: [0.28466219 0.52110264 0.59627036 0.16494629 0.91696245 0.95985218]
# Erro do modelo: [ 0.28466219  0.52110264 -0.40372964  0.16494629 -0.08303755 -0.04014782]
# Valores de pesos: [ 1.24001298 -0.46717767]
# Valor de bias: -0.9942046061877072
#
# Treinamento do Modelo na Iteração 973
# Previsão antes da função de ativação: [-0.92213579  0.08428835  0.389946   -1.62290229  2.40279429  3.1756296 ]
# Previsão depois da função de ativação: [0.28452291 0.52105962 0.5962697  0.164805   0.91704013 0.95990681]
# Erro do modelo: [ 0.28452291  0.52105962 -0.4037303   0.164805   -0.08295987 -0.04009319]
# Valores de pesos: [ 1.24063815 -0.4674054 ]
# Valor de bias: -0.9949439464684757
#
# Treinamento do Modelo na Iteração 974
# Previsão antes da função de ativação: [-0.92281931  0.08411614  0.38994348 -1.62392742  2.40381437  3.17704711]
# Previsão depois da função de ativação: [0.28438379 0.52101664 0.59626909 0.16466394 0.91711771 0.95996132]
# Erro do modelo: [ 0.28438379  0.52101664 -0.40373091  0.16466394 -0.08288229 -0.04003868]
# Valores de pesos: [ 1.24126274 -0.46763281]
# Valor de bias: -0.9956829672987983
#
# Treinamento do Modelo na Iteração 975
# Previsão antes da função de ativação: [-0.92350226  0.08394407  0.38994118 -1.62495149  2.40483385  3.17846377]
# Previsão depois da função de ativação: [0.28424482 0.5209737  0.59626854 0.16452313 0.91719517 0.96001574]
# Erro do modelo: [ 0.28424482  0.5209737  -0.40373146  0.16452313 -0.08280483 -0.03998426]
# Valores de pesos: [ 1.24188675 -0.4678599 ]
# Valor de bias: -0.9964216691323563
#
# Treinamento do Modelo na Iteração 976
# Previsão antes da função de ativação: [-0.92418466  0.08377215  0.38993911 -1.6259745   2.40585272  3.17987958]
# Previsão depois da função de ativação: [0.28410601 0.5209308  0.59626804 0.16438256 0.91727252 0.96007005]
# Erro do modelo: [ 0.28410601  0.5209308  -0.40373196  0.16438256 -0.08272748 -0.03992995]
# Valores de pesos: [ 1.24251019 -0.46808665]
# Valor de bias: -0.9971600524218526
#
# Treinamento do Modelo na Iteração 977
# Previsão antes da função de ativação: [-0.92486649  0.08360037  0.38993726 -1.62699647  2.406871    3.18129454]
# Previsão depois da função de ativação: [0.28396735 0.52088793 0.5962676  0.16424223 0.91734975 0.96012426]
# Erro do modelo: [ 0.28396735  0.52088793 -0.4037324   0.16424223 -0.08265025 -0.03987574]
# Valores de pesos: [ 1.24313306 -0.46831308]
# Valor de bias: -0.9978981176190141
#
# Treinamento do Modelo na Iteração 978
# Previsão antes da função de ativação: [-0.92554777  0.08342875  0.38993564 -1.62801739  2.40788867  3.18270864]
# Previsão depois da função de ativação: [0.28382885 0.5208451  0.59626721 0.16410214 0.91742688 0.96017836]
# Erro do modelo: [ 0.28382885  0.5208451  -0.40373279  0.16410214 -0.08257312 -0.03982164]
# Valores de pesos: [ 1.24375534 -0.46853918]
# Valor de bias: -0.9986358651745951
#
# Treinamento do Modelo na Iteração 979
# Previsão antes da função de ativação: [-0.92622848  0.08325727  0.38993424 -1.62903726  2.40890574  3.1841219 ]
# Previsão depois da função de ativação: [0.2836905  0.5208023  0.59626687 0.16396229 0.91750389 0.96023236]
# Erro do modelo: [ 0.2836905   0.5208023  -0.40373313  0.16396229 -0.08249611 -0.03976764]
# Valores de pesos: [ 1.24437706 -0.46876496]
# Valor de bias: -0.9993732955383792
#
# Treinamento do Modelo na Iteração 980
# Previsão antes da função de ativação: [-0.92690864  0.08308593  0.38993306 -1.63005609  2.40992221  3.18553431]
# Previsão depois da função de ativação: [0.2835523  0.52075954 0.59626659 0.16382268 0.9175808  0.96028626]
# Erro do modelo: [ 0.2835523   0.52075954 -0.40373341  0.16382268 -0.0824192  -0.03971374]
# Valores de pesos: [ 1.2449982  -0.46899042]
# Valor de bias: -1.0001104091591821
#
# Treinamento do Modelo na Iteração 981
# Previsão antes da função de ativação: [-0.92758825  0.08291474  0.38993211 -1.63107387  2.41093809  3.18694587]
# Previsão depois da função de ativação: [0.28341426 0.52071682 0.59626636 0.1636833  0.91765759 0.96034006]
# Erro do modelo: [ 0.28341426  0.52071682 -0.40373364  0.1636833  -0.08234241 -0.03965994]
# Valores de pesos: [ 1.24561877 -0.46921554]
# Valor de bias: -1.0008472064848546
#
# Treinamento do Modelo na Iteração 982
# Previsão antes da função de ativação: [-0.9282673   0.0827437   0.38993138 -1.63209061  2.41195337  3.18835659]
# Previsão depois da função de ativação: [0.28327637 0.52067413 0.59626618 0.16354417 0.91773428 0.96039376]
# Erro do modelo: [ 0.28327637  0.52067413 -0.40373382  0.16354417 -0.08226572 -0.03960624]
# Valores de pesos: [ 1.24623876 -0.46944035]
# Valor de bias: -1.0015836879622848
#
# Treinamento do Modelo na Iteração 983
# Previsão antes da função de ativação: [-0.92894579  0.0825728   0.38993086 -1.63310632  2.41296805  3.18976646]
# Previsão depois da função de ativação: [0.28313864 0.52063148 0.59626606 0.16340527 0.91781085 0.96044735]
# Erro do modelo: [ 0.28313864  0.52063148 -0.40373394  0.16340527 -0.08218915 -0.03955265]
# Valores de pesos: [ 1.24685819 -0.46966483]
# Valor de bias: -1.0023198540374008
#
# Treinamento do Modelo na Iteração 984
# Previsão antes da função de ativação: [-0.92962374  0.08240204  0.38993057 -1.63412098  2.41398213  3.19117549]
# Previsão depois da função de ativação: [0.28300106 0.52058886 0.59626599 0.16326661 0.91788732 0.96050084]
# Erro do modelo: [ 0.28300106  0.52058886 -0.40373401  0.16326661 -0.08211268 -0.03949916]
# Valores de pesos: [ 1.24747705 -0.46988899]
# Valor de bias: -1.0030557051551736
#
# Treinamento do Modelo na Iteração 985
# Previsão antes da função de ativação: [-0.93030113  0.08223143  0.3899305  -1.63513461  2.41499561  3.19258368]
# Previsão depois da função de ativação: [0.28286363 0.52054628 0.59626597 0.16312818 0.91796367 0.96055423]
# Erro do modelo: [ 0.28286363  0.52054628 -0.40373403  0.16312818 -0.08203633 -0.03944577]
# Valores de pesos: [ 1.24809534 -0.47011283]
# Valor de bias: -1.0037912417596193
#
# Treinamento do Modelo na Iteração 986
# Previsão antes da função de ativação: [-0.93097797  0.08206096  0.38993065 -1.6361472   2.41600851  3.19399102]
# Previsão depois da função de ativação: [0.28272635 0.52050374 0.596266   0.16299    0.91803991 0.96060752]
# Erro do modelo: [ 0.28272635  0.52050374 -0.403734    0.16299    -0.08196009 -0.03939248]
# Valores de pesos: [ 1.24871306 -0.47033634]
# Valor de bias: -1.004526464293802
#
# Treinamento do Modelo na Iteração 987
# Previsão antes da função de ativação: [-0.93165425  0.08189064  0.38993102 -1.63715877  2.4170208   3.19539753]
# Previsão depois da função de ativação: [0.28258922 0.52046123 0.59626609 0.16285204 0.91811605 0.96066071]
# Erro do modelo: [ 0.28258922  0.52046123 -0.40373391  0.16285204 -0.08188395 -0.03933929]
# Valores de pesos: [ 1.24933022 -0.47055954]
# Valor de bias: -1.0052613731998363
#
# Treinamento do Modelo na Iteração 988
# Previsão antes da função de ativação: [-0.93232999  0.08172046  0.38993161 -1.6381693   2.41803251  3.19680319]
# Previsão depois da função de ativação: [0.28245225 0.52041875 0.59626623 0.16271432 0.91819208 0.9607138 ]
# Erro do modelo: [ 0.28245225  0.52041875 -0.40373377  0.16271432 -0.08180792 -0.0392862 ]
# Valores de pesos: [ 1.24994681 -0.47078241]
# Valor de bias: -1.0059959689188898
#
# Treinamento do Modelo na Iteração 989
# Previsão antes da função de ativação: [-0.93300518  0.08155042  0.38993241 -1.6391788   2.41904362  3.19820802]
# Previsão depois da função de ativação: [0.28231543 0.52037631 0.59626643 0.16257683 0.918268   0.96076679]
# Erro do modelo: [ 0.28231543  0.52037631 -0.40373357  0.16257683 -0.081732   -0.03923321]
# Valores de pesos: [ 1.25056283 -0.47100496]
# Valor de bias: -1.0067302518911854
#
# Treinamento do Modelo na Iteração 990
# Previsão antes da função de ativação: [-0.93367983  0.08138053  0.38993343 -1.64018727  2.42005414  3.19961201]
# Previsão depois da função de ativação: [0.28217875 0.52033391 0.59626667 0.16243958 0.9183438  0.96081967]
# Erro do modelo: [ 0.28217875  0.52033391 -0.40373333  0.16243958 -0.0816562  -0.03918033]
# Valores de pesos: [ 1.2511783 -0.4712272]
# Valor de bias: -1.0074642225560047
#
# Treinamento do Modelo na Iteração 991
# Previsão antes da função de ativação: [-0.93435392  0.08121077  0.38993467 -1.64119472  2.42106406  3.20101516]
# Previsão depois da função de ativação: [0.28204223 0.52029154 0.59626697 0.16230256 0.91841951 0.96087246]
# Erro do modelo: [ 0.28204223  0.52029154 -0.40373303  0.16230256 -0.08158049 -0.03912754]
# Valores de pesos: [ 1.25179319 -0.47144911]
# Valor de bias: -1.0081978813516894
#
# Treinamento do Modelo na Iteração 992
# Previsão antes da função de ativação: [-0.93502747  0.08104116  0.38993613 -1.64220115  2.4220734   3.20241748]
# Previsão depois da função de ativação: [0.28190586 0.52024921 0.59626732 0.16216577 0.9184951  0.96092515]
# Erro do modelo: [ 0.28190586  0.52024921 -0.40373268  0.16216577 -0.0815049  -0.03907485]
# Valores de pesos: [ 1.25240753 -0.47167071]
# Valor de bias: -1.0089312287156451
#
# Treinamento do Modelo na Iteração 993
# Previsão antes da função de ativação: [-0.93570048  0.08087169  0.3899378  -1.64320655  2.42308215  3.20381896]
# Previsão depois da função de ativação: [0.28176964 0.52020691 0.59626773 0.16202922 0.91857058 0.96097774]
# Erro do modelo: [ 0.28176964  0.52020691 -0.40373227  0.16202922 -0.08142942 -0.03902226]
# Valores de pesos: [ 1.2530213  -0.47189199]
# Valor de bias: -1.0096642650843428
#
# Treinamento do Modelo na Iteração 994
# Previsão antes da função de ativação: [-0.93637294  0.08070237  0.38993969 -1.64421093  2.4240903   3.20521962]
# Previsão depois da função de ativação: [0.28163357 0.52016465 0.59626818 0.16189289 0.91864596 0.96103023]
# Erro do modelo: [ 0.28163357  0.52016465 -0.40373182  0.16189289 -0.08135404 -0.03896977]
# Valores de pesos: [ 1.25363452 -0.47211296]
# Valor de bias: -1.0103969908933217
#
# Treinamento do Modelo na Iteração 995
# Previsão antes da função de ativação: [-0.93704486  0.08053318  0.38994179 -1.64521429  2.42509787  3.20661944]
# Previsão depois da função de ativação: [0.28149765 0.52012242 0.59626869 0.1617568  0.91872123 0.96108262]
# Erro do modelo: [ 0.28149765  0.52012242 -0.40373131  0.1617568  -0.08127877 -0.03891738]
# Valores de pesos: [ 1.25424717 -0.4723336 ]
# Valor de bias: -1.011129406577192
#
# Treinamento do Modelo na Iteração 996
# Previsão antes da função de ativação: [-0.93771624  0.08036414  0.38994411 -1.64621664  2.42610485  3.20801842]
# Previsão depois da função de ativação: [0.28136188 0.52008023 0.59626924 0.16162094 0.91879639 0.96113491]
# Erro do modelo: [ 0.28136188  0.52008023 -0.40373076  0.16162094 -0.08120361 -0.03886509]
# Valores de pesos: [ 1.25485927 -0.47255393]
# Valor de bias: -1.0118615125696375
#
# Treinamento do Modelo na Iteração 997
# Previsão antes da função de ativação: [-0.93838707  0.08019523  0.38994664 -1.64721797  2.42711124  3.20941658]
# Previsão depois da função de ativação: [0.28122626 0.52003807 0.59626985 0.1614853  0.91887145 0.96118711]
# Erro do modelo: [ 0.28122626  0.52003807 -0.40373015  0.1614853  -0.08112855 -0.03881289]
# Valores de pesos: [ 1.25547081 -0.47277395]
# Valor de bias: -1.0125933093034172
#
# Treinamento do Modelo na Iteração 998
# Previsão antes da função de ativação: [-0.93905737  0.08002647  0.38994938 -1.64821829  2.42811705  3.21081391]
# Previsão depois da função de ativação: [0.28109079 0.51999595 0.59627051 0.1613499  0.91894639 0.9612392 ]
# Erro do modelo: [ 0.28109079  0.51999595 -0.40372949  0.1613499  -0.08105361 -0.0387608 ]
# Valores de pesos: [ 1.25608179 -0.47299365]
# Valor de bias: -1.013324797210369
#
# Treinamento do Modelo na Iteração 999
# Previsão antes da função de ativação: [-0.93972712  0.07985784  0.38995234 -1.64921759  2.42912227  3.21221041]
# Previsão depois da função de ativação: [0.28095547 0.51995386 0.59627123 0.16121472 0.91902124 0.9612912 ]
# Erro do modelo: [ 0.28095547  0.51995386 -0.40372877  0.16121472 -0.08097876 -0.0387088 ]
# Valores de pesos: [ 1.25669221 -0.47321303]
# Valor de bias: -1.0140559767214115
#
# Treinamento Concluído!

# %% [markdown]
# ## Parte 4 - Avaliação do Modelo

# %%
# Dados de teste (2 registros)
X_teste = np.array([[1.5, 2], [4, 5.5]])
y_teste = np.array([0, 1])

# %%
# Faz previsões com o modelo treinado usando dados de teste
previsoes_teste = modelo_dsa.predict(X_teste)
# Out:
# Previsão antes de passar pela função de ativação: [-0.07544372  1.41004121]
# Previsão depois de passar pela função de ativação: [0.48114801 0.80377244]

# %%
# Bloco if para avaliar os resultados 
for i, previsao in enumerate(previsoes_teste):
    
    # Extrai os valores reais de entrada e saída
    entrada = X_teste[i]
    saida = y_teste[i]
    
    # Checando o resultado
    if previsao == 0:
        print(f"\nEntrada {entrada} e saída {saida} a previsão foi {previsao}: Não é Transação Suspeita")
    else:
        print(f"\nEntrada {entrada} e saida {saida} a previsão foi {previsao}: É Transação Suspeita")

print("\n")
# Out:
# Entrada [1.5 2. ] e saída 0 a previsão foi 0: Não é Transação Suspeita
#
# Entrada [4.  5.5] e saida 1 a previsão foi 1: É Transação Suspeita

# %% [markdown]
# ## Parte 5 - Deploy do Modelo

# %%
# Cria matriz de novos dados de entrada
novos_dados = np.array([[1, 2], [4, 5]])

# %%
# Faz previsões com o modelo treinado
previsoes_novos_dados = modelo_dsa.predict(novos_dados)
# Out:
# Previsão antes de passar pela função de ativação: [-0.70378982  1.64664772]
# Previsão depois de passar pela função de ativação: [0.33097251 0.83843747]

# %%
# Bloco if para avaliar os resultados 
for i, previsao in enumerate(previsoes_novos_dados):
    
    # Extrai os valores de entrada 
    entrada = novos_dados[i]
    
    # Checando o resultado
    if previsao == 0:
        print(f"\nPara os atributos de entrada {entrada} a previsão foi {previsao}: Não é Transação Suspeita")
    else:
        print(f"\nPara os atributos de entrada {entrada} a previsão foi {previsao}: É Transação Suspeita")
# Out:
# Para os atributos de entrada [1 2] a previsão foi 0: Não é Transação Suspeita
#
# Para os atributos de entrada [4 5] a previsão foi 1: É Transação Suspeita

# %%
# %reload_ext watermark
# %watermark -a "Data Science Academy"
# Out:
# Author: Data Science Academy

# %%
#%watermark -v -m

# %%
#%watermark --iversions

# %% [markdown]
# ## Fim
